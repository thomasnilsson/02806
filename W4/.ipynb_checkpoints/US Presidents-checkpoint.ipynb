# %%
import pandas as pd

# %%
data = pd.read_csv('data/pres.csv', header=None).drop("0", 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-ee42a898962c> in <module>()
# ----> 1 data = pd.read_csv('data/pres.csv', header=None).drop("0", 1)
#
# /Users/thomasnilsson/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, level, inplace, errors)
#    2048                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2049             else:
# -> 2050                 new_axis = axis.drop(labels, errors=errors)
#    2051             dropped = self.reindex(**{axis_name: new_axis})
#    2052             try:
#
# /Users/thomasnilsson/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    3573             if errors != 'ignore':
#    3574                 raise ValueError('labels %s not contained in axis' %
# -> 3575                                  labels[mask])
# ...

# %%
data
# Out:
#      0            1    2
# 1    2        Adams   48
# 2    3    Jefferson   96
# 3    4      Madison   96
# 4    5       Monroe   96
# 5    6        Adams   48
# 6    7      Jackson   96
# 7    8    Van Buren   48
# 8    9     Harrison    1
# 9   10        Tyler   47
# 10  11         Polk   48
# 11  12       Taylor   16
# 12  13      Filmore   32
# 13  14       Pierce   48
# 14  15     Buchanan   48
# 15  16      Lincoln   49
# 16  17      Johnson   47
# 17  18        Grant   96
# 18  19        Hayes   48
# 19  20     Garfield    7
# 20  21       Arthur   41
# 21  22    Cleveland   48
# 22  23     Harrison   48
# 23  24    Cleveland   48
# 24  25     McKinley   54
# 25  26    Roosevelt   90
# 26  27         Taft   48
# 27  28       Wilson   96
# 28  29      Harding   29
# 29  30     Coolidge   67
# 30  31       Hoover   48
# 31  32    Roosevelt  146
# 32  33       Truman   92
# 33  34   Eisenhower   96
# 34  35      Kennedy   34
# 35  36      Johnson   62
# 36  37        Nixon   67
# ...

# %%
for x in range(25):
    y = x*x / 2
    z = int(y + 0.5)
    s = str(x) + ", " + str(z)
    print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-61c68a53536a> in <module>()
#       2     y = x*x / 2
#       3     z = int(y + 0.5)
# ----> 4     print(x + ", " + z)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
